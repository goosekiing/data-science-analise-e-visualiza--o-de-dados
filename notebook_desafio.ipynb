# %% [markdown]
# # Espaço de desafios
#
# Notebook para o desenvolvimento de códigos de desafio do curso Data Visualization: estilização de tabelas com Python.
#
# ### Dicionário de variáveis
#
# * **pais**: país de destino do produto.
# * **id_cliente**: código de identificação do cliente solicitante.
# * **data_pedido**: data de solicitação do produto por parte do cliente.
# * **data_chegada**: data de chegada do produto ao endereço de entrega informado pelo cliente.
# * **tipo_compra**: categoria que se enquadra a compra, podendo ser *Normal* ou *Devolução*.
# * **numero_pedido**: código de identificação da compra realizada.
# * **tamanho_pacote**: tamanho do pacote para envio do pedido.
# * **unidades**: quantidade de unidades compradas no pedido.
# * **custo_empacotamento**: valor do custo da loja para empacotar o produto.
# * **custo_envio**: valor do custo da loja para enviar o produto.
# * **tipo_desconto**: categoria do tipo de desconto foi aplicado.
# * **categoria**: categoria de tipo de produto.
# * **tipo_consumo**: nível de consumo do produto por tempo de uso.
# * **tipo_cliente**: categoria de tipo de cliente.
# * **custo_produto**: valor total do custo que o pedido resulta para a loja.

# %% [markdown]
# ## Hora da prática 1

# %%
import pandas as pd
df_d1 = pd.read_csv("loja_livro_filmes.csv")
df_d1
# Out:
#             pais  id_cliente data_pedido data_chegada tipo_compra  \
# 0      Argentina   111962928  2002-02-15   2002-03-10      Normal
# 1      Argentina   145148150  2004-11-05   2004-11-26      Normal
# 2      Argentina   194622983  2014-09-14   2014-09-28      Normal
# 3      Argentina   220834258  2011-07-20   2011-07-30   Devolução
# 4      Argentina   220834258  2013-09-15   2017-02-15      Normal
# ...          ...         ...         ...          ...         ...
# 24885  Venezuela   890670789  2006-05-05   2006-05-18   Devolução
# 24886  Venezuela   892274535  2002-02-20   2002-03-08      Normal
# 24887  Venezuela   892274535  2015-01-26   2015-02-17      Normal
# 24888  Venezuela   898039697  2002-08-22   2002-09-06      Normal
# 24889  Venezuela   898039697  2009-05-27   2009-06-17      Normal
#
#        numero_pedido  tamanho_pacote  unidades  custo_empacotamento  \
# 0           98091426  Pacote pequeno         1                  3.0
# 1           98087803  Pacote pequeno         3                  1.0
# 2           98072296  Pacote pequeno         1                  3.0
# 3           98077986  Pacote pequeno         2                  1.0
# 4           98074234  Pacote pequeno         1                  2.0
# ...              ...             ...       ...                  ...
# 24885       98085835  Pacote pequeno         2                  1.0
# 24886       98091414  Pacote pequeno         1                  2.0
# 24887       98071516  Pacote pequeno         3                  3.0
# 24888       98090720  Pacote pequeno         2                  2.0
# 24889       98081676  Pacote pequeno         1                  1.0
#
#        custo_envio tipo_desconto categoria  tipo_consumo tipo_cliente  \
# 0             5.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 1             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 2             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 3             3.86  Cyber Monday   BlueRay  Alto Consumo          B2B
# 4             4.88  Black Friday   BlueRay  Alto Consumo          B2B
# ...            ...           ...       ...           ...          ...
# 24885         6.99  Sem desconto     Livro  Alto Consumo          B2C
# 24886         6.25  Cyber Monday     Livro  Alto Consumo          B2B
# 24887         4.65  Sem desconto     Livro  Alto Consumo          B2B
# 24888         4.58  Sem desconto     Livro  Alto Consumo          B2B
# 24889         6.65  Sem desconto     Livro  Alto Consumo          B2B
#
#        custo_produto
# 0               8.99
# 1               7.99
# 2               9.99
# 3               4.86
# 4               6.88
# ...              ...
# 24885           7.99
# 24886           8.25
# 24887           7.65
# 24888           6.58
# 24889           7.65
#
# [24890 rows x 15 columns]

# %%
df_d1_paises = df_d1.groupby(["pais"])["unidades"].sum().nlargest(9).copy()
df_d1_paises = df_d1_paises.reset_index()
df_d1_paises
# Out:
#         pais  unidades
# 0  Argentina      5591
# 1    Equador      5566
# 2   Paraguai      5564
# 3       Peru      5550
# 4  Venezuela      5529
# 5   Colômbia      5504
# 6     Brasil      5473
# 7    Uruguai      5377
# 8      Chile      5304

# %%
df_d1_paises.columns = ["País", "Unidades Pedidas"]
df_d1_paises["Ranking"]=df_d1_paises.index+1
df_d1_paises.set_index("Ranking", inplace=True)
df_d1_paises
# Out:
#               País  Unidades Pedidas
# Ranking
# 1        Argentina              5591
# 2          Equador              5566
# 3         Paraguai              5564
# 4             Peru              5550
# 5        Venezuela              5529
# 6         Colômbia              5504
# 7           Brasil              5473
# 8          Uruguai              5377
# 9            Chile              5304

# %%
s_d1_paises = df_d1_paises.style
s_d1_paises = s_d1_paises.format({"Unidades Pedidas": "{} prod"})
s_d1_paises
# Out:
# <style type="text/css">
# </style>
# <table id="T_752f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_752f9_level0_col0" class="col_heading level0 col0" >País</th>
#       <th id="T_752f9_level0_col1" class="col_heading level0 col1" >Unidades Pedidas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_752f9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_752f9_row0_col0" class="data row0 col0" >Argentina</td>
#       <td id="T_752f9_row0_col1" class="data row0 col1" >5591 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_752f9_row1_col0" class="data row1 col0" >Equador</td>
#       <td id="T_752f9_row1_col1" class="data row1 col1" >5566 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_752f9_row2_col0" class="data row2 col0" >Paraguai</td>
#       <td id="T_752f9_row2_col1" class="data row2 col1" >5564 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_752f9_row3_col0" class="data row3 col0" >Peru</td>
#       <td id="T_752f9_row3_col1" class="data row3 col1" >5550 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_752f9_row4_col0" class="data row4 col0" >Venezuela</td>
#       <td id="T_752f9_row4_col1" class="data row4 col1" >5529 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_752f9_row5_col0" class="data row5 col0" >Colômbia</td>
#       <td id="T_752f9_row5_col1" class="data row5 col1" >5504 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_752f9_row6_col0" class="data row6 col0" >Brasil</td>
#       <td id="T_752f9_row6_col1" class="data row6 col1" >5473 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_752f9_row7_col0" class="data row7 col0" >Uruguai</td>
#       <td id="T_752f9_row7_col1" class="data row7 col1" >5377 prod</td>
#     </tr>
#     <tr>
#       <th id="T_752f9_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_752f9_row8_col0" class="data row8 col0" >Chile</td>
#       <td id="T_752f9_row8_col1" class="data row8 col1" >5304 prod</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hora da prática 2

# %%
df_d2_produto_custo=df_d1.groupby(["categoria"])[["custo_produto"]].sum().copy()
df_d2_produto_custo
# Out:
#            custo_produto
# categoria
# BlueRay         14191.36
# CD              10514.28
# Coleção         73128.59
# Livro           78213.80

# %%
df_d2_produto_custo.columns = ["Custo do produto"]
df_d2_produto_custo.index.name = "Categoria"
df_d2_produto_custo
# Out:
#            Custo do produto
# Categoria
# BlueRay            14191.36
# CD                 10514.28
# Coleção            73128.59
# Livro              78213.80

# %%
s_d2_produto_custo = df_d2_produto_custo.style
s_d2_produto_custo
# Out:
# <style type="text/css">
# </style>
# <table id="T_f14db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f14db_level0_col0" class="col_heading level0 col0" >Custo do produto</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f14db_level0_row0" class="row_heading level0 row0" >BlueRay</th>
#       <td id="T_f14db_row0_col0" class="data row0 col0" >14191.360000</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row1" class="row_heading level0 row1" >CD</th>
#       <td id="T_f14db_row1_col0" class="data row1 col0" >10514.280000</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row2" class="row_heading level0 row2" >Coleção</th>
#       <td id="T_f14db_row2_col0" class="data row2 col0" >73128.590000</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row3" class="row_heading level0 row3" >Livro</th>
#       <td id="T_f14db_row3_col0" class="data row3 col0" >78213.800000</td>
#     </tr>
#   </tbody>
# </table>

# %%
s_d2_produto_custo.format("R$ {:,.2f}")\
                  .highlight_min(color="green")\
                  .highlight_max(color="#C3514E")
# Out:
# <style type="text/css">
# #T_f14db_row1_col0 {
#   background-color: green;
# }
# #T_f14db_row3_col0 {
#   background-color: #C3514E;
# }
# </style>
# <table id="T_f14db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f14db_level0_col0" class="col_heading level0 col0" >Custo do produto</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f14db_level0_row0" class="row_heading level0 row0" >BlueRay</th>
#       <td id="T_f14db_row0_col0" class="data row0 col0" >R$ 14,191.36</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row1" class="row_heading level0 row1" >CD</th>
#       <td id="T_f14db_row1_col0" class="data row1 col0" >R$ 10,514.28</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row2" class="row_heading level0 row2" >Coleção</th>
#       <td id="T_f14db_row2_col0" class="data row2 col0" >R$ 73,128.59</td>
#     </tr>
#     <tr>
#       <th id="T_f14db_level0_row3" class="row_heading level0 row3" >Livro</th>
#       <td id="T_f14db_row3_col0" class="data row3 col0" >R$ 78,213.80</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hora da prática 3

# %%
df_d3_descontos = pd.DataFrame(df_d1["tipo_desconto"].value_counts())
df_d3_descontos
# Out:
#                count
# tipo_desconto
# Sem desconto   13347
# Cyber Monday    6922
# Black Friday    1986
# Liquidação      1487
# Data especial   1148

# %%
df_d3_descontos.columns = ["N° Pedidos"]
df_d3_descontos.index.name = "Tipo de Desconto"
df_d3_descontos
# Out:
#                   N° Pedidos
# Tipo de Desconto
# Sem desconto           13347
# Cyber Monday            6922
# Black Friday            1986
# Liquidação              1487
# Data especial           1148

# %%
import numpy as np

# %%
porcentagem = df_d3_descontos["N° Pedidos"]
porcentagem = 100 * porcentagem / porcentagem.sum()
porcentagem
# Out:
# Tipo de Desconto
# Sem desconto     53.623945
# Cyber Monday     27.810366
# Black Friday      7.979108
# Liquidação        5.974287
# Data especial     4.612294
# Name: N° Pedidos, dtype: float64

# %%
df_d3_descontos["Distribuição de Pedidos"] = porcentagem
df_d3_descontos
# Out:
#                   N° Pedidos  Distribuição de Pedidos
# Tipo de Desconto
# Sem desconto           13347                53.623945
# Cyber Monday            6922                27.810366
# Black Friday            1986                 7.979108
# Liquidação              1487                 5.974287
# Data especial           1148                 4.612294

# %%
s_d3_descontos = df_d3_descontos.style
s_d3_descontos
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4885">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4885_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_f4885_level0_col1" class="col_heading level0 col1" >Distribuição de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4885_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_f4885_row0_col0" class="data row0 col0" >13347</td>
#       <td id="T_f4885_row0_col1" class="data row0 col1" >53.623945</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_f4885_row1_col0" class="data row1 col0" >6922</td>
#       <td id="T_f4885_row1_col1" class="data row1 col1" >27.810366</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_f4885_row2_col0" class="data row2 col0" >1986</td>
#       <td id="T_f4885_row2_col1" class="data row2 col1" >7.979108</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_f4885_row3_col0" class="data row3 col0" >1487</td>
#       <td id="T_f4885_row3_col1" class="data row3 col1" >5.974287</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_f4885_row4_col0" class="data row4 col0" >1148</td>
#       <td id="T_f4885_row4_col1" class="data row4 col1" >4.612294</td>
#     </tr>
#   </tbody>
# </table>

# %%
s_d3_descontos.format({"N° Pedidos": "{:,}", "Distribuição de Pedidos": "{:.2f} %"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4885">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4885_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_f4885_level0_col1" class="col_heading level0 col1" >Distribuição de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4885_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_f4885_row0_col0" class="data row0 col0" >13,347</td>
#       <td id="T_f4885_row0_col1" class="data row0 col1" >53.62 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_f4885_row1_col0" class="data row1 col0" >6,922</td>
#       <td id="T_f4885_row1_col1" class="data row1 col1" >27.81 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_f4885_row2_col0" class="data row2 col0" >1,986</td>
#       <td id="T_f4885_row2_col1" class="data row2 col1" >7.98 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_f4885_row3_col0" class="data row3 col0" >1,487</td>
#       <td id="T_f4885_row3_col1" class="data row3 col1" >5.97 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_f4885_row4_col0" class="data row4 col0" >1,148</td>
#       <td id="T_f4885_row4_col1" class="data row4 col1" >4.61 %</td>
#     </tr>
#   </tbody>
# </table>

# %%
cabeçalho = {
    "selector": "th",
    "props": "color: black; background-color: white; font-weight: bold;"
}

celulas = {
    "selector": "td",
    "props": "color: black; background-color: white;"
}

s_d3_descontos.set_table_styles([cabeçalho, celulas])
s_d3_descontos.bar(subset="Distribuição de Pedidos", vmax=100, vmin=0, color="blue", height=75)
# Out:
# <style type="text/css">
# #T_f4885 th {
#   color: black;
#   background-color: white;
#   font-weight: bold;
# }
# #T_f4885 td {
#   color: black;
#   background-color: white;
# }
# #T_f4885_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 53.6%, transparent 53.6%) no-repeat center;
#   background-size: 100% 75.0%;
# }
# #T_f4885_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 27.8%, transparent 27.8%) no-repeat center;
#   background-size: 100% 75.0%;
# }
# #T_f4885_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 8.0%, transparent 8.0%) no-repeat center;
#   background-size: 100% 75.0%;
# }
# #T_f4885_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 6.0%, transparent 6.0%) no-repeat center;
#   background-size: 100% 75.0%;
# }
# #T_f4885_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 4.6%, transparent 4.6%) no-repeat center;
#   background-size: 100% 75.0%;
# }
# </style>
# <table id="T_f4885">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4885_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_f4885_level0_col1" class="col_heading level0 col1" >Distribuição de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4885_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_f4885_row0_col0" class="data row0 col0" >13,347</td>
#       <td id="T_f4885_row0_col1" class="data row0 col1" >53.62 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_f4885_row1_col0" class="data row1 col0" >6,922</td>
#       <td id="T_f4885_row1_col1" class="data row1 col1" >27.81 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_f4885_row2_col0" class="data row2 col0" >1,986</td>
#       <td id="T_f4885_row2_col1" class="data row2 col1" >7.98 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_f4885_row3_col0" class="data row3 col0" >1,487</td>
#       <td id="T_f4885_row3_col1" class="data row3 col1" >5.97 %</td>
#     </tr>
#     <tr>
#       <th id="T_f4885_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_f4885_row4_col0" class="data row4 col0" >1,148</td>
#       <td id="T_f4885_row4_col1" class="data row4 col1" >4.61 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hora da prática 4

# %%
df_d1["data_chegada"] = pd.to_datetime(df_d1["data_chegada"])
df_d1["data_pedido"] = pd.to_datetime(df_d1["data_pedido"])

# %%
df_d4_datas=df_d1.copy()
df_d4_datas = df_d4_datas.sort_values("data_pedido")
df_d4_datas = df_d4_datas.reset_index(drop=True)
df_d4_datas
# Out:
#            pais  id_cliente data_pedido data_chegada tipo_compra  \
# 0      Paraguai   733376144  1999-12-12   2000-01-04      Normal
# 1       Uruguai   131591686  1999-12-15   2000-01-03      Normal
# 2       Uruguai   476846252  1999-12-15   2000-01-03      Normal
# 3          Peru   561944200  1999-12-15   2000-01-04      Normal
# 4      Paraguai   783214027  1999-12-16   2000-01-04   Devolução
# ...         ...         ...         ...          ...         ...
# 24885   Uruguai   605633342  2015-12-14   2015-12-28      Normal
# 24886      Peru   111962928  2015-12-15   2016-01-03      Normal
# 24887   Equador   758679810  2015-12-15   2016-01-04      Normal
# 24888    Brasil   436608095  2015-12-15   2015-12-26   Devolução
# 24889  Colômbia   667298873  2015-12-15   2016-01-02      Normal
#
#        numero_pedido  tamanho_pacote  unidades  custo_empacotamento  \
# 0           98094261   Pacote grande         2                  2.0
# 1           98094257   Pacote grande         3                  3.0
# 2           98094256  Pacote pequeno         1                  3.0
# 3           98094260  Pacote pequeno         2                  2.0
# 4           98094259   Pacote grande         3                  2.0
# ...              ...             ...       ...                  ...
# 24885       98069382   Pacote grande         3                  1.0
# 24886       98069376   Pacote grande         1                  1.0
# 24887       98069373  Pacote pequeno         3                  1.0
# 24888       98069377  Pacote pequeno         1                  3.0
# 24889       98069374   Pacote grande         2                  1.0
#
#        custo_envio tipo_desconto categoria   tipo_consumo tipo_cliente  \
# 0             4.55  Sem desconto   Coleção  Baixo Consumo          B2B
# 1             3.99  Sem desconto   Coleção   Alto Consumo          B2C
# 2             6.14  Sem desconto     Livro  Baixo Consumo          B2C
# 3             3.25  Sem desconto     Livro  Baixo Consumo          B2C
# 4             5.61  Sem desconto   Coleção   Alto Consumo          B2B
# ...            ...           ...       ...            ...          ...
# 24885         5.33  Sem desconto   Coleção   Alto Consumo          B2B
# 24886         5.99  Sem desconto        CD  Baixo Consumo          B2C
# 24887         3.55  Cyber Monday     Livro  Baixo Consumo          B2C
# 24888         3.20  Sem desconto     Livro   Alto Consumo          B2B
# 24889         3.20  Sem desconto   Coleção   Alto Consumo          B2C
#
#        custo_produto
# 0               6.55
# 1               6.99
# 2               9.14
# 3               5.25
# 4               7.61
# ...              ...
# 24885           6.33
# 24886           6.99
# 24887           4.55
# 24888           6.20
# 24889           4.20
#
# [24890 rows x 15 columns]

# %%
df_d4_datas = df_d4_datas[df_d4_datas["data_pedido"] >= "2013-01-01"]
df_d4_datas["meses"] = df_d4_datas["data_pedido"].dt.strftime("%Y - %b")
df_d4_datas
# Out:
# C:\Users\Gustavo S Schultz\AppData\Local\Temp\ipykernel_3396\1711014640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d4_datas["meses"] = df_d4_datas["data_pedido"].dt.strftime("%Y - %b")
#            pais  id_cliente data_pedido data_chegada tipo_compra  \
# 18777     Chile   318601696  2013-01-01   2013-01-17      Normal
# 18778   Uruguai   405991354  2013-01-01   2016-11-27   Devolução
# 18779     Chile   356602040  2013-01-01   2013-01-11      Normal
# 18780     Chile   405991354  2013-01-02   2013-01-21      Normal
# 18781   Uruguai   619383446  2013-01-02   2013-01-22   Devolução
# ...         ...         ...         ...          ...         ...
# 24885   Uruguai   605633342  2015-12-14   2015-12-28      Normal
# 24886      Peru   111962928  2015-12-15   2016-01-03      Normal
# 24887   Equador   758679810  2015-12-15   2016-01-04      Normal
# 24888    Brasil   436608095  2015-12-15   2015-12-26   Devolução
# 24889  Colômbia   667298873  2015-12-15   2016-01-02      Normal
#
#        numero_pedido  tamanho_pacote  unidades  custo_empacotamento  \
# 18777       98075481  Pacote pequeno         3                  1.0
# 18778       98075486   Pacote grande         1                  3.0
# 18779       98075484  Pacote pequeno         2                  3.0
# 18780       98075479  Pacote pequeno         2                  3.0
# 18781       98075482   Pacote grande         3                  3.0
# ...              ...             ...       ...                  ...
# 24885       98069382   Pacote grande         3                  1.0
# 24886       98069376   Pacote grande         1                  1.0
# 24887       98069373  Pacote pequeno         3                  1.0
# 24888       98069377  Pacote pequeno         1                  3.0
# 24889       98069374   Pacote grande         2                  1.0
#
#        custo_envio  tipo_desconto categoria   tipo_consumo tipo_cliente  \
# 18777         4.73   Sem desconto     Livro   Alto Consumo          B2B
# 18778         5.84     Liquidação   Coleção   Alto Consumo          B2C
# 18779         6.12   Black Friday     Livro  Baixo Consumo          B2C
# 18780         5.75  Data especial   BlueRay   Alto Consumo          B2C
# 18781         3.58   Sem desconto   Coleção   Alto Consumo          B2C
# ...            ...            ...       ...            ...          ...
# 24885         5.33   Sem desconto   Coleção   Alto Consumo          B2B
# 24886         5.99   Sem desconto        CD  Baixo Consumo          B2C
# 24887         3.55   Cyber Monday     Livro  Baixo Consumo          B2C
# 24888         3.20   Sem desconto     Livro   Alto Consumo          B2B
# 24889         3.20   Sem desconto   Coleção   Alto Consumo          B2C
#
#        custo_produto       meses
# 18777           5.73  2013 - Jan
# 18778           8.84  2013 - Jan
# 18779           9.12  2013 - Jan
# 18780           8.75  2013 - Jan
# 18781           6.58  2013 - Jan
# ...              ...         ...
# 24885           6.33  2015 - Dec
# 24886           6.99  2015 - Dec
# 24887           4.55  2015 - Dec
# 24888           6.20  2015 - Dec
# 24889           4.20  2015 - Dec
#
# [6113 rows x 16 columns]

# %%
tempo_entrega = df_d4_datas["data_chegada"]-df_d4_datas["data_pedido"]
df_d4_datas["tempo_entrega"] = tempo_entrega
df_d4_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6113 entries, 18777 to 24889
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pais                 6113 non-null   object
#  1   id_cliente           6113 non-null   int64
#  2   data_pedido          6113 non-null   datetime64[ns]
#  3   data_chegada         6113 non-null   datetime64[ns]
#  4   tipo_compra          6113 non-null   object
#  5   numero_pedido        6113 non-null   int64
#  6   tamanho_pacote       6113 non-null   object
#  7   unidades             6113 non-null   int64
#  8   custo_empacotamento  6113 non-null   float64
#  9   custo_envio          6113 non-null   float64
#  10  tipo_desconto        6113 non-null   object
#  11  categoria            6113 non-null   object
#  12  tipo_consumo         6113 non-null   object
#  13  tipo_cliente         6113 non-null   object
#  14  custo_produto        6113 non-null   float64
#  15  meses                6113 non-null   object
#  16  tempo_entrega        6113 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(3), object(8), timedelta64[ns](1)
# memory usage: 859.6+ KB
# C:\Users\Gustavo S Schultz\AppData\Local\Temp\ipykernel_3396\4234204087.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d4_datas["tempo_entrega"] = tempo_entrega

# %%
df_d4_entregas = df_d4_datas.pivot_table(index="pais", columns="meses", values="tempo_entrega", aggfunc="mean", sort=False)
df_d4_entregas = df_d4_entregas.dt.strftime("%Y - %b")
df_d4_entregas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3396\358486705.py in ?()
#       1 df_d4_entregas = df_d4_datas.pivot_table(index="pais", columns="meses", values="tempo_entrega", aggfunc="mean", sort=False)
# ----> 2 df_d4_entregas = df_d4_entregas.dt.strftime("%Y - %b")
#       3 df_d4_entregas
#
# c:\Users\Gustavo S Schultz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dt'

# %%
s_d4_entregas = df_d4_entregas.style
s_d4_entregas.set_sticky(axis="index")
# Out:
# <style type="text/css">
# #T_fe8f7 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_fe8f7 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_fe8f7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >meses</th>
#       <th id="T_fe8f7_level0_col0" class="col_heading level0 col0" >2013 - Jan</th>
#       <th id="T_fe8f7_level0_col1" class="col_heading level0 col1" >2013 - Feb</th>
#       <th id="T_fe8f7_level0_col2" class="col_heading level0 col2" >2013 - Mar</th>
#       <th id="T_fe8f7_level0_col3" class="col_heading level0 col3" >2013 - Apr</th>
#       <th id="T_fe8f7_level0_col4" class="col_heading level0 col4" >2013 - May</th>
#       <th id="T_fe8f7_level0_col5" class="col_heading level0 col5" >2013 - Jun</th>
#       <th id="T_fe8f7_level0_col6" class="col_heading level0 col6" >2013 - Jul</th>
#       <th id="T_fe8f7_level0_col7" class="col_heading level0 col7" >2013 - Aug</th>
#       <th id="T_fe8f7_level0_col8" class="col_heading level0 col8" >2013 - Sep</th>
#       <th id="T_fe8f7_level0_col9" class="col_heading level0 col9" >2013 - Oct</th>
#       <th id="T_fe8f7_level0_col10" class="col_heading level0 col10" >2013 - Nov</th>
#       <th id="T_fe8f7_level0_col11" class="col_heading level0 col11" >2013 - Dec</th>
#       <th id="T_fe8f7_level0_col12" class="col_heading level0 col12" >2014 - Jan</th>
#       <th id="T_fe8f7_level0_col13" class="col_heading level0 col13" >2014 - Feb</th>
#       <th id="T_fe8f7_level0_col14" class="col_heading level0 col14" >2014 - Mar</th>
#       <th id="T_fe8f7_level0_col15" class="col_heading level0 col15" >2014 - Apr</th>
#       <th id="T_fe8f7_level0_col16" class="col_heading level0 col16" >2014 - May</th>
#       <th id="T_fe8f7_level0_col17" class="col_heading level0 col17" >2014 - Jun</th>
#       <th id="T_fe8f7_level0_col18" class="col_heading level0 col18" >2014 - Jul</th>
#       <th id="T_fe8f7_level0_col19" class="col_heading level0 col19" >2014 - Aug</th>
#       <th id="T_fe8f7_level0_col20" class="col_heading level0 col20" >2014 - Sep</th>
#       <th id="T_fe8f7_level0_col21" class="col_heading level0 col21" >2014 - Oct</th>
#       <th id="T_fe8f7_level0_col22" class="col_heading level0 col22" >2014 - Nov</th>
#       <th id="T_fe8f7_level0_col23" class="col_heading level0 col23" >2014 - Dec</th>
#       <th id="T_fe8f7_level0_col24" class="col_heading level0 col24" >2015 - Jan</th>
#       <th id="T_fe8f7_level0_col25" class="col_heading level0 col25" >2015 - Feb</th>
#       <th id="T_fe8f7_level0_col26" class="col_heading level0 col26" >2015 - Mar</th>
#       <th id="T_fe8f7_level0_col27" class="col_heading level0 col27" >2015 - Apr</th>
#       <th id="T_fe8f7_level0_col28" class="col_heading level0 col28" >2015 - May</th>
#       <th id="T_fe8f7_level0_col29" class="col_heading level0 col29" >2015 - Jun</th>
#       <th id="T_fe8f7_level0_col30" class="col_heading level0 col30" >2015 - Jul</th>
#       <th id="T_fe8f7_level0_col31" class="col_heading level0 col31" >2015 - Aug</th>
#       <th id="T_fe8f7_level0_col32" class="col_heading level0 col32" >2015 - Sep</th>
#       <th id="T_fe8f7_level0_col33" class="col_heading level0 col33" >2015 - Oct</th>
#       <th id="T_fe8f7_level0_col34" class="col_heading level0 col34" >2015 - Nov</th>
#       <th id="T_fe8f7_level0_col35" class="col_heading level0 col35" >2015 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pais</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe8f7_level0_row0" class="row_heading level0 row0" >Chile</th>
#       <td id="T_fe8f7_row0_col0" class="data row0 col0" >90 days 05:03:09.473684211</td>
#       <td id="T_fe8f7_row0_col1" class="data row0 col1" >341 days 05:38:49.411764704</td>
#       <td id="T_fe8f7_row0_col2" class="data row0 col2" >470 days 02:40:00</td>
#       <td id="T_fe8f7_row0_col3" class="data row0 col3" >351 days 16:48:00</td>
#       <td id="T_fe8f7_row0_col4" class="data row0 col4" >195 days 13:05:27.272727272</td>
#       <td id="T_fe8f7_row0_col5" class="data row0 col5" >99 days 17:36:00</td>
#       <td id="T_fe8f7_row0_col6" class="data row0 col6" >307 days 05:32:18.461538460</td>
#       <td id="T_fe8f7_row0_col7" class="data row0 col7" >207 days 22:09:13.846153846</td>
#       <td id="T_fe8f7_row0_col8" class="data row0 col8" >321 days 01:30:00</td>
#       <td id="T_fe8f7_row0_col9" class="data row0 col9" >137 days 16:48:00</td>
#       <td id="T_fe8f7_row0_col10" class="data row0 col10" >80 days 16:00:00</td>
#       <td id="T_fe8f7_row0_col11" class="data row0 col11" >285 days 16:36:55.384615384</td>
#       <td id="T_fe8f7_row0_col12" class="data row0 col12" >633 days 20:18:27.692307696</td>
#       <td id="T_fe8f7_row0_col13" class="data row0 col13" >483 days 18:00:00</td>
#       <td id="T_fe8f7_row0_col14" class="data row0 col14" >658 days 05:13:02.608695656</td>
#       <td id="T_fe8f7_row0_col15" class="data row0 col15" >252 days 14:24:00</td>
#       <td id="T_fe8f7_row0_col16" class="data row0 col16" >309 days 19:45:52.941176472</td>
#       <td id="T_fe8f7_row0_col17" class="data row0 col17" >469 days 18:51:25.714285712</td>
#       <td id="T_fe8f7_row0_col18" class="data row0 col18" >149 days 21:20:00</td>
#       <td id="T_fe8f7_row0_col19" class="data row0 col19" >358 days 10:06:18.947368420</td>
#       <td id="T_fe8f7_row0_col20" class="data row0 col20" >403 days 20:00:00</td>
#       <td id="T_fe8f7_row0_col21" class="data row0 col21" >341 days 02:49:24.705882352</td>
#       <td id="T_fe8f7_row0_col22" class="data row0 col22" >327 days 03:00:00</td>
#       <td id="T_fe8f7_row0_col23" class="data row0 col23" >329 days 10:17:08.571428572</td>
#       <td id="T_fe8f7_row0_col24" class="data row0 col24" >530 days 06:51:25.714285712</td>
#       <td id="T_fe8f7_row0_col25" class="data row0 col25" >549 days 01:36:00</td>
#       <td id="T_fe8f7_row0_col26" class="data row0 col26" >606 days 06:43:12</td>
#       <td id="T_fe8f7_row0_col27" class="data row0 col27" >424 days 01:32:54.193548384</td>
#       <td id="T_fe8f7_row0_col28" class="data row0 col28" >423 days 10:17:08.571428568</td>
#       <td id="T_fe8f7_row0_col29" class="data row0 col29" >353 days 19:49:33.913043480</td>
#       <td id="T_fe8f7_row0_col30" class="data row0 col30" >432 days 15:25:42.857142856</td>
#       <td id="T_fe8f7_row0_col31" class="data row0 col31" >447 days 11:22:06.315789472</td>
#       <td id="T_fe8f7_row0_col32" class="data row0

# %% [markdown]
# ## Hora da prática 5

# %%
## Ler o arquivo
df = df_d1

## Preparar os dados

# Criar um DataFrame alternativo para ter um nome de coluna coerente com a visualização
df_alteracao = df.rename(columns={'pais': 'Custo por país ($)'})

# Agrupar os dados de tipo de cliente, com a categoria de produtos e os países que esses clientes importam o produto
df_clientes = df_alteracao.pivot_table(index=['tipo_cliente', 'categoria'], columns = 'Custo por país ($)', values = 'custo_produto', aggfunc = 'sum')

# Renomear o cabeçalho para nomes mais coerentes
df_clientes.rename_axis(index={'tipo_cliente': 'Tipo cliente', 'categoria': 'Categoria produto'}, inplace = True)

# Adicionar uma coluna que mostra a soma dos custos por tipo de cliente e categoria de produto
df_clientes['Total ($)'] = df_clientes.sum(axis=1)

## Criar a visualização
s_clientes = df_clientes.style.format('{:,.2f}')

# Criar os estilos base para a tabela, a partir da padronização das fontes, plano de fundo para branco e o alinhamento do cabeçalho para o topo
tabela = {
    'selector': 'td, th',
    'props': 'font-weight: normal; font-family: Arial; text-align: right; background-color: white; color: black;'
}
# Alinhar verticalmente o cabeçalho para o topo permite a pessoa observadora identificar onde começa a hierarquização dos grupos B2B e B2C
cabecalho = {
    'selector': 'th',
    'props': 'vertical-align: top'
}
s_clientes.set_table_styles([tabela, cabecalho])

# Adicionar linha de separação do cabeçalho superior
# Destacar as categorias que mais geraram custo com a aplicação de negrito nas fontes
s_clientes.set_table_styles({
    ('B2B', 'BlueRay'): [{'selector': 'th', 'props': 'border-top: 1px solid #181818'},
              {'selector': 'td', 'props': 'border-top: 1px solid #181818'}],
    ('B2B', 'Livro'): [{'selector': 'th', 'props': 'font-weight: bold'}],
    ('B2C', 'Livro'): [{'selector': 'th', 'props': 'font-weight: bold'}],
}, overwrite=False, axis=1)

# Destacar os elementos em cada tipo de cliente que mais geraram custos com uma seleção
s_clientes.set_table_styles({
    'Total ($)': [{
        'selector': '.true',
        'props': 'font-weight: bold'
    }]
},overwrite=False,axis=0)

cores_coluna = pd.DataFrame(['false','false','false','true','false','false','false','true'],index= df_clientes['Total ($)'].index,
                            columns = ['Total ($)'])
# Visualização final
s_clientes.set_td_classes(cores_coluna)
# Out:
# <style type="text/css">
# #T_0e927 td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
#   color: black;
# }
# #T_0e927  th {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
#   color: black;
# }
# #T_0e927 th {
#   vertical-align: top;
# }
# #T_0e927 th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_0e927 td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_0e927 th.row3 {
#   font-weight: bold;
# }
# #T_0e927 th.row7 {
#   font-weight: bold;
# }
# #T_0e927 .true.col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0e927">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Custo por país ($)</th>
#       <th id="T_0e927_level0_col0" class="col_heading level0 col0" >Argentina</th>
#       <th id="T_0e927_level0_col1" class="col_heading level0 col1" >Brasil</th>
#       <th id="T_0e927_level0_col2" class="col_heading level0 col2" >Chile</th>
#       <th id="T_0e927_level0_col3" class="col_heading level0 col3" >Colômbia</th>
#       <th id="T_0e927_level0_col4" class="col_heading level0 col4" >Equador</th>
#       <th id="T_0e927_level0_col5" class="col_heading level0 col5" >Paraguai</th>
#       <th id="T_0e927_level0_col6" class="col_heading level0 col6" >Peru</th>
#       <th id="T_0e927_level0_col7" class="col_heading level0 col7" >Uruguai</th>
#       <th id="T_0e927_level0_col8" class="col_heading level0 col8" >Venezuela</th>
#       <th id="T_0e927_level0_col9" class="col_heading level0 col9" >Total ($)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo cliente</th>
#       <th class="index_name level1" >Categoria produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e927_level0_row0" class="row_heading level0 row0" rowspan="4">B2B</th>
#       <th id="T_0e927_level1_row0" class="row_heading level1 row0" >BlueRay</th>
#       <td id="T_0e927_row0_col0" class="data row0 col0" >488.23</td>
#       <td id="T_0e927_row0_col1" class="data row0 col1" >552.31</td>
#       <td id="T_0e927_row0_col2" class="data row0 col2" >521.31</td>
#       <td id="T_0e927_row0_col3" class="data row0 col3" >538.39</td>
#       <td id="T_0e927_row0_col4" class="data row0 col4" >473.88</td>
#       <td id="T_0e927_row0_col5" class="data row0 col5" >596.74</td>
#       <td id="T_0e927_row0_col6" class="data row0 col6" >727.11</td>
#       <td id="T_0e927_row0_col7" class="data row0 col7" >580.81</td>
#       <td id="T_0e927_row0_col8" class="data row0 col8" >476.67</td>
#       <td id="T_0e927_row0_col9" class="data row0 col9 false" >4,955.45</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row1" class="row_heading level1 row1" >CD</th>
#       <td id="T_0e927_row1_col0" class="data row1 col0" >344.74</td>
#       <td id="T_0e927_row1_col1" class="data row1 col1" >449.66</td>
#       <td id="T_0e927_row1_col2" class="data row1 col2" >350.58</td>
#       <td id="T_0e927_row1_col3" class="data row1 col3" >422.22</td>
#       <td id="T_0e927_row1_col4" class="data row1 col4" >396.15</td>
#       <td id="T_0e927_row1_col5" class="data row1 col5" >341.49</td>
#       <td id="T_0e927_row1_col6" class="data row1 col6" >388.17</td>
#       <td id="T_0e927_row1_col7" class="data row1 col7" >495.02</td>
#       <td id="T_0e927_row1_col8" class="data row1 col8" >415.60</td>
#       <td id="T_0e927_row1_col9" class="data row1 col9 false" >3,603.63</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row2" class="row_heading level1 row2" >Coleção</th>
#       <td id="T_0e927_row2_col0" class="data row2 col0" >2,824.31</td>
#       <td id="T_0e927_row2_col1" class="data row2 col1" >2,899.26</td>
#       <td id="T_0e927_row2_col2" class="data row2 col2" >2,939.29</td>
#       <td id="T_0e927_row2_col3" class="data row2 col3" >2,823.34</td>
#       <td id="T_0e927_row2_col4" class="data row2 col4" >2,747.09</td>
#       <td id="T_0e927_row2_col5" class="data row2 col5" >2,492.20</td>
#       <td id="T_0e927_row2_col6" class="data row2 col6" >2,912.78</td>
#       <td id="T_0e927_row2_col7" class="data row2 col7" >2,548.28</td>
#       <td id="T_0e927_row2_col8" class="data row2 col8" >2,969.67</td>
#       <td id="T_0e927_row2_col9" class="data row2 col9 false" >25,156.22</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row3" class="row_heading level1 row3" >Livro</th>
#       <td id="T_0e927_row3_col0" class="data row3 col0" >3,150.77</td>
#       <td id="T_0e927_row3_col1" class="data row3 col1" >2,751.26</td>
#       <td id="T_0e927_row3_col2" class="data row3 col2" >2,809.13</td>
#       <td id="T_0e927_row3_col3" class="data row3 col3" >2,987.06</td>
#       <td id="T_0e927_row3_col4" class="data row3 col4" >3,229.24</td>
#       <td id="T_0e927_row3_col5" class="data row3 col5" >3,161.33</td>
#       <td id="T_0e927_row3_col6" class="data row3 col6" >3,092.14</td>
#       <td id="T_0e927_row3_col7" class="data row3 col7" >2,872.69</td>
#       <td id="T_0e927_row3_col8" class="data row3 col8" >2,721.60</td>
#       <td id="T_0e927_row3_col9" class="data row3 col9 true" >26,775.22</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level0_row4" class="row_heading level0 row4" rowspan="4">B2C</th>
#       <th id="T_0e927_level1_row4" class="row_heading level1 row4" >BlueRay</th>
#       <td id="T_0e927_row4_col0" class="data row4 col0" >1,027.85</td>
#       <td id="T_0e927_row4_col1" class="data row4 col1" >1,007.18</td>
#       <td id="T_0e927_row4_col2" class="data row4 col2" >992.12</td>
#       <td id="T_0e927_row4_col3" class="data row4 col3" >1,062.35</td>
#       <td id="T_0e927_row4_col4" class="data row4 col4" >1,004.99</td>
#       <td id="T_0e927_row4_col5" class="data row4 col5" >1,095.01</td>
#       <td id="T_0e927_row4_col6" class="data row4 col6" >1,079.54</td>
#       <td id="T_0e927_row4_col7" class="data row4 col7" >873.96</td>
#       <td id="T_0e927_row4_col8" class="data row4 col8" >1,092.91</td>
#       <td id="T_0e927_row4_col9" class="data row4 col9 false" >9,235.91</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row5" class="row_heading level1 row5" >CD</th>
#       <td id="T_0e927_row5_col0" class="data row5 col0" >785.63</td>
#       <td id="T_0e927_row5_col1" class="data row5 col1" >860.71</td>
#       <td id="T_0e927_row5_col2" class="data row5 col2" >620.83</td>
#       <td id="T_0e927_row5_col3" class="data row5 col3" >668.12</td>
#       <td id="T_0e927_row5_col4" class="data row5 col4" >666.49</td>
#       <td id="T_0e927_row5_col5" class="data row5 col5" >867.01</td>
#       <td id="T_0e927_row5_col6" class="data row5 col6" >788.82</td>
#       <td id="T_0e927_row5_col7" class="data row5 col7" >795.89</td>
#       <td id="T_0e927_row5_col8" class="data row5 col8" >857.15</td>
#       <td id="T_0e927_row5_col9" class="data row5 col9 false" >6,910.65</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row6" class="row_heading level1 row6" >Coleção</th>
#       <td id="T_0e927_row6_col0" class="data row6 col0" >5,587.93</td>
#       <td id="T_0e927_row6_col1" class="data row6 col1" >5,053.64</td>
#       <td id="T_0e927_row6_col2" class="data row6 col2" >5,162.34</td>
#       <td id="T_0e927_row6_col3" class="data row6 col3" >5,253.09</td>
#       <td id="T_0e927_row6_col4" class="data row6 col4" >5,583.83</td>
#       <td id="T_0e927_row6_col5" class="data row6 col5" >5,759.34</td>
#       <td id="T_0e927_row6_col6" class="data row6 col6" >5,159.96</td>
#       <td id="T_0e927_row6_col7" class="data row6 col7" >4,961.45</td>
#       <td id="T_0e927_row6_col8" class="data row6 col8" >5,450.79</td>
#       <td id="T_0e927_row6_col9" class="data row6 col9 false" >47,972.37</td>
#     </tr>
#     <tr>
#       <th id="T_0e927_level1_row7" class="row_heading level1 row7" >Livro</t
